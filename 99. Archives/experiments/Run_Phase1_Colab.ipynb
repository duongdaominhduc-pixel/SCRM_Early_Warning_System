# %% [markdown]
# # SCRM Phase 1 (SOTA Overhaul) - Google Colab Runner
#
# Đây là notebook được tạo tự động bởi AI Agent để chạy trên Google Colab với GPU.

# %%
# Bước 1: Kết nối với Google Drive của bạn
from google.colab import drive
drive.mount('/content/drive')

# %%
# Bước 2: Trỏ đường dẫn tới thư mục BBKH trên Drive của bạn
# Lưu ý: Bạn cần upload toàn bộ folder BBKH (bao gồm code và data) lên Drive.
# Hãy sửa đường dẫn bên dưới cho khớp với vị trí bạn lưu folder BBKH trên Drive.
import os
# %cd "/content/drive/MyDrive/BBKH"
# Nếu bạn để trong thư mục khác, ví dụ: %cd "/content/drive/MyDrive/Research/BBKH"

# %%
# Bước 3: Cài đặt thư viện Deep Learning
# !pip install torch transformers datasets scikit-learn pandas numpy matplotlib

# %%
# Bước 4: Chạy toàn bộ Pipeline Phase 1
# !python run_phase1_pipeline.py
